# %%
1.Introduction & Business Problem:
A restaurant is a business which prepares and serves food and drink to customers in return for money, either paid before the meal, after the meal, or with an open account. The City of New York is famous for its excellent cuisine. So, it is evident that to survive in such competitive market it is very important to strategically plan. Various factors need to be studied in order to decide on the Location such as:
New York Population
New York City Demographics
Are there any Farmers Markets, Wholesale markets etc nearby so that the ingredients can be purchased fresh to maintain quality and cost?
Are there any venues like Gyms, Entertainment zones, Parks etc nearby where floating population is high etc
Who are the competitors in that location?
Cuisine served / Menu of the competitors
Segmentation of the Borough Even though well-funded XYZ Company Ltd. need to choose the correct location to start its first venture. If this is successful, they can replicate the same in other locations. This would interest anyone who wants to start a new restaurant in New York city.
2. Data:
One city will be analysed in this project: New York City. We will be using the below datasets for analysing New York city
Data 1: Neighbourhood has a total of 5 boroughs and 306 neighbourhoods. In order to segment the neighbourhoods and explore them, we will essentially need a dataset that contains the 5 boroughs and the neighbourhoods that exist in each borough as well as the latitude and longitude coordinates of each neighbourhood. Data source: https://cocl.us/new_york_dataset Description: This data set contains the required information. And we will use this data set to explore various neighbourhoods of New York city.
Date 2: Indian restaurants in each neighbourhood of New York city. Data source: Foursquare API Description: By using this api we will get all the venues in each neighbourhood. We can filter these venues to get only Indian restaurants. Data 3: GeoSpace data Data source: https://data.cityofnewyork.us/City-Government/Borough-Boundaries/tqmj-j8zm Description: By using this geo space data we will get the New York Borough boundaries that will help us visualize choropleth map.
Analysis
We will import the required libraries for python.
pandas and numpy for handling data.
request module for using FourSquare API.
geopy to get co-ordinates of City of New York.
folium to visualize the results on a map

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import requests
from bs4 import BeautifulSoup

import os
# !conda install -c conda-forge folium
import folium # map rendering library
# !conda install -c conda-forge geocoder
# !conda install -c conda-forge geopy --yes
import geocoder
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     folium-0.11.0              |             py_0          61 KB  conda-forge
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     branca-0.4.2               |     pyhd8ed1ab_0          26 KB  conda-forge
#     _openmp_mutex-4.5          |            1_gnu          22 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     openssl-1.1.1i             |       h7f98852_0         2.1 MB  conda-forge
#     certifi-2020.12.5          |   py36h5fab9bb_0         143 KB  conda-forge
#     libgomp-9.3.0              |      h5dbcf3e_17         378 KB  conda-forge
#     libgcc-ng-9.3.0            |      h5dbcf3e_17         7.8 MB  conda-forge
#     ca-certificates-2020.12.5  |       ha878542_0         137 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        10.6 MB
#
# The following NEW packages will be INSTALLED:
#
#     _openmp_mutex:   4.5-1_gnu                conda-forge
#     branca:          0.4.2-pyhd8ed1ab_0       conda-forge
#     folium:          0.11.0-py_0              conda-forge
#     libgomp:         9.3.0-h5dbcf3e_17        conda-forge
#     python_abi:      3.6-1_cp36m              conda-forge
#
# The following packages will be UPDATED:
#
#     _libgcc_mutex:   0.1-main                             --> 0.1-conda_forge          conda-forge
#     ca-certificates: 2020.10.14-0                         --> 2020.12.5-ha878542_0     conda-forge
#     certifi:         2020.12.5-py36h06a4308_0             --> 2020.12.5-py36h5fab9bb_0 conda-forge
#     libgcc-ng:       8.2.0-hdf63c60_1                     --> 9.3.0-h5dbcf3e_17        conda-forge
#     openssl:         1.1.1i-h27cfd23_0                    --> 1.1.1i-h7f98852_0        conda-forge
#
#
# Downloading and Extracting Packages
# folium-0.11.0        | 61 KB     | ##################################### | 100%
# _libgcc_mutex-0.1    | 3 KB      | ##################################### | 100%
# branca-0.4.2         | 26 KB     | ##################################### | 100%
# _openmp_mutex-4.5    | 22 KB     | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# openssl-1.1.1i       | 2.1 MB    | ##################################### | 100%
# certifi-2020.12.5    | 143 KB    | ##################################### | 100%
# libgomp-9.3.0        | 378 KB    | ##################################### | 100%
# libgcc-ng-9.3.0      | 7.8 MB    | ##################################### | 100%
# ca-certificates-2020 | 137 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: -
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geocoder
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geocoder-1.38.1            |             py_1          53 KB  conda-forge
#     ratelim-0.1.6              |             py_2           6 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          59 KB
#
# The following NEW packages will be INSTALLED:
#
#     geocoder: 1.38.1-py_1 conda-forge
#     ratelim:  0.1.6-py_2  conda-forge
#
#
# Downloading and Extracting Packages
# geocoder-1.38.1      | 53 KB     | ##################################### | 100%
# ratelim-0.1.6        | 6 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-2.1.0                |     pyhd3deb0d_0          64 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          98 KB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.50-py_0          conda-forge
#     geopy:         2.1.0-pyhd3deb0d_0 conda-forge
#
#
# Downloading and Extracting Packages
# geopy-2.1.0          | 64 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %%
def geo_location(address):
    # get geo location of address
    geolocator = Nominatim(user_agent="ny_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude

# %%
def get_venues(lat,lng):
    
    #set variables
    radius=1000
    LIMIT=100
    CLIENT_ID = '0G0KFCU55P01WMUAE5ZSE1NRPQQIP5F0J5EY1ZI0IKHQDNYG' # your Foursquare ID
    CLIENT_SECRET = 'QU5PJIGT233ERHLCAVAPFPLYPGJ1KDN1YJYTFJHRBADVWJWM' # your Foursquare Secret
    VERSION = '20180605' # Foursquare API version
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results["response"]['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
        
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
def get_venue_details(venue_id):
        
    CLIENT_ID = '0G0KFCU55P01WMUAE5ZSE1NRPQQIP5F0J5EY1ZI0IKHQDNYG' # your Foursquare ID
    CLIENT_SECRET = 'QU5PJIGT233ERHLCAVAPFPLYPGJ1KDN1YJYTFJHRBADVWJWM'# your Foursquare Secret
    VERSION = '20180605' # Foursquare API version
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
        
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
def get_new_york_data():
    url='https://cocl.us/new_york_dataset'
    resp=requests.get(url).json()
    # all data is present in features label
    features=resp['features']
    
    # define the dataframe columns
    column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
    # instantiate the dataframe
    new_york_data = pd.DataFrame(columns=column_names)
    
    for data in features:
        borough = data['properties']['borough'] 
        neighborhood_name = data['properties']['name']
        
        neighborhood_latlon = data['geometry']['coordinates']
        neighborhood_lat = neighborhood_latlon[1]
        neighborhood_lon = neighborhood_latlon[0]
    
        new_york_data = new_york_data.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    
    return new_york_data

# %%
# get new york data
new_york_data=get_new_york_data()

# %%
new_york_data.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
new_york_data.shape
# Out:
# (306, 4)

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Neighborhood for each Borough in New York City')
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('No.of Neighborhood', fontsize=15)
#giving a bar plot
new_york_data.groupby('Borough')['Neighborhood'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
# prepare neighborhood list that contains indian restaurants
column_names=['Borough', 'Neighborhood', 'ID','Name']
indian_rest_ny=pd.DataFrame(columns=column_names)
count=1
for row in new_york_data.values.tolist():
    Borough, Neighborhood, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    indian_restaurants=venues[venues['Category']=='Indian Restaurant']   
    print('(',count,'/',len(new_york_data),')','Indian Restaurants in '+Neighborhood+', '+Borough+':'+str(len(indian_restaurants)))
    for restaurant_detail in indian_restaurants.values.tolist():
        id, name , category=restaurant_detail
        indian_rest_ny = indian_rest_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
# Out:
# ( 1 / 306 ) Indian Restaurants in Wakefield, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Co-op City, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Eastchester, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Fieldston, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Riverdale, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Kingsbridge, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Marble Hill, Manhattan:0
# ( 1 / 306 ) Indian Restaurants in Woodlawn, Bronx:1
# ( 1 / 306 ) Indian Restaurants in Norwood, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Williamsbridge, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Baychester, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Pelham Parkway, Bronx:0
# ( 1 / 306 ) Indian Restaurants in City Island, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Bedford Park, Bronx:0
# ( 1 / 306 ) Indian Restaurants in University Heights, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Morris Heights, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Fordham, Bronx:0
# ( 1 / 306 ) Indian Restaurants in East Tremont, Bronx:0
# ( 1 / 306 ) Indian Restaurants in West Farms, Bronx:0
# ( 1 / 306 ) Indian Restaurants in High  Bridge, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Melrose, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Mott Haven, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Port Morris, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Longwood, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Hunts Point, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Morrisania, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Soundview, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Clason Point, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Throgs Neck, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Country Club, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Parkchester, Bronx:1
# ( 1 / 306 ) Indian Restaurants in Westchester Square, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Van Nest, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Morris Park, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Belmont, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Spuyten Duyvil, Bronx:1
# ( 1 / 306 ) Indian Restaurants in North Riverdale, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Pelham Bay, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Schuylerville, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Edgewater Park, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Castle Hill, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Olinville, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Pelham Gardens, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Concourse, Bronx:1
# ( 1 / 306 ) Indian Restaurants in Unionport, Bronx:1
# ( 1 / 306 ) Indian Restaurants in Edenwald, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Bay Ridge, Brooklyn:1
# ( 1 / 306 ) Indian Restaurants in Bensonhurst, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Sunset Park, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Greenpoint, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Gravesend, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Brighton Beach, Brooklyn:1
# ( 1 / 306 ) Indian Restaurants in Sheepshead Bay, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Manhattan Terrace, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Flatbush, Brooklyn:2
# ( 1 / 306 ) Indian Restaurants in Crown Heights, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in East Flatbush, Brooklyn:1
# ( 1 / 306 ) Indian Restaurants in Kensington, Brooklyn:2
# ( 1 / 306 ) Indian Restaurants in Windsor Terrace, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Prospect Heights, Brooklyn:1
# ( 1 / 306 ) Indian Restaurants in Brownsville, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Williamsburg, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Bushwick, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Bedford Stuyvesant, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Brooklyn Heights, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Cobble Hill, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Carroll Gardens, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Red Hook, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Gowanus, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Fort Greene, Brooklyn:1
# ( 1 / 306 ) Indian Restaurants in Park Slope, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Cypress Hills, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in East New York, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Starrett City, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Canarsie, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Flatlands, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Mill Island, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Manhattan Beach, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Coney Island, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Bath Beach, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Borough Park, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Dyker Heights, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Gerritsen Beach, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Marine Park, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Clinton Hill, Brooklyn:1
# ( 1 / 306 ) Indian Restaurants in Sea Gate, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Downtown, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Boerum Hill, Brooklyn:1
# ( 1 / 306 ) Indian Restaurants in Prospect Lefferts Gardens, Brooklyn:2
# ( 1 / 306 ) Indian Restaurants in Ocean Hill, Brooklyn:2
# ( 1 / 306 ) Indian Restaurants in City Line, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Bergen Beach, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Midwood, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Prospect Park South, Brooklyn:2
# ( 1 / 306 ) Indian Restaurants in Georgetown, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in East Williamsburg, Brooklyn:1
# ( 1 / 306 ) Indian Restaurants in North Side, Brooklyn:1
# ( 1 / 306 ) Indian Restaurants in South Side, Brooklyn:1
# ( 1 / 306 ) Indian Restaurants in Ocean Parkway, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Fort Hamilton, Brooklyn:1
# ( 1 / 306 ) Indian Restaurants in Chinatown, Manhattan:0
# ( 1 / 306 ) Indian Restaurants in Washington Heights, Manhattan:1
# ( 1 / 306 ) Indian Restaurants in Inwood, Manhattan:0
# ( 1 / 306 ) Indian Restaurants in Hamilton Heights, Manhattan:2
# ( 1 / 306 ) Indian Restaurants in Manhattanville, Manhattan:2
# ( 1 / 306 ) Indian Restaurants in Central Harlem, Manhattan:2
# ( 1 / 306 ) Indian Restaurants in East Harlem, Manhattan:1
# ( 1 / 306 ) Indian Restaurants in Upper East Side, Manhattan:0
# ( 1 / 306 ) Indian Restaurants in Yorkville, Manhattan:2
# ( 1 / 306 ) Indian Restaurants in Lenox Hill, Manhattan:0
# ( 1 / 306 ) Indian Restaurants in Roosevelt Island, Manhattan:1
# ( 1 / 306 ) Indian Restaurants in Upper West Side, Manhattan:3
# ( 1 / 306 ) Indian Restaurants in Lincoln Square, Manhattan:0
# ( 1 / 306 ) Indian Restaurants in Clinton, Manhattan:0
# ( 1 / 306 ) Indian Restaurants in Midtown, Manhattan:1
# ( 1 / 306 ) Indian Restaurants in Murray Hill, Manhattan:1
# ( 1 / 306 ) Indian Restaurants in Chelsea, Manhattan:1
# ( 1 / 306 ) Indian Restaurants in Greenwich Village, Manhattan:0
# ( 1 / 306 ) Indian Restaurants in East Village, Manhattan:0
# ( 1 / 306 ) Indian Restaurants in Lower East Side, Manhattan:0
# ( 1 / 306 ) Indian Restaurants in Tribeca, Manhattan:1
# ( 1 / 306 ) Indian Restaurants in Little Italy, Manhattan:0
# ( 1 / 306 ) Indian Restaurants in Soho, Manhattan:0
# ( 1 / 306 ) Indian Restaurants in West Village, Manhattan:1
# ( 1 / 306 ) Indian Restaurants in Manhattan Valley, Manhattan:4
# ( 1 / 306 ) Indian Restaurants in Morningside Heights, Manhattan:1
# ( 1 / 306 ) Indian Restaurants in Gramercy, Manhattan:4
# ( 1 / 306 ) Indian Restaurants in Battery Park City, Manhattan:0
# ( 1 / 306 ) Indian Restaurants in Financial District, Manhattan:1
# ( 1 / 306 ) Indian Restaurants in Astoria, Queens:3
# ( 1 / 306 ) Indian Restaurants in Woodside, Queens:8
# ( 1 / 306 ) Indian Restaurants in Jackson Heights, Queens:7
# ( 1 / 306 ) Indian Restaurants in Elmhurst, Queens:3
# ( 1 / 306 ) Indian Restaurants in Howard Beach, Queens:0
# ( 1 / 306 ) Indian Restaurants in Corona, Queens:0
# ( 1 / 306 ) Indian Restaurants in Forest Hills, Queens:0
# ( 1 / 306 ) Indian Restaurants in Kew Gardens, Queens:2
# ( 1 / 306 ) Indian Restaurants in Richmond Hill, Queens:8
# ( 1 / 306 ) Indian Restaurants in Flushing, Queens:0
# ( 1 / 306 ) Indian Restaurants in Long Island City, Queens:2
# ( 1 / 306 ) Indian Restaurants in Sunnyside, Queens:1
# ( 1 / 306 ) Indian Restaurants in East Elmhurst, Queens:0
# ( 1 / 306 ) Indian Restaurants in Maspeth, Queens:0
# ( 1 / 306 ) Indian Restaurants in Ridgewood, Queens:1
# ( 1 / 306 ) Indian Restaurants in Glendale, Queens:0
# ( 1 / 306 ) Indian Restaurants in Rego Park, Queens:1
# ( 1 / 306 ) Indian Restaurants in Woodhaven, Queens:0
# ( 1 / 306 ) Indian Restaurants in Ozone Park, Queens:0
# ( 1 / 306 ) Indian Restaurants in South Ozone Park, Queens:1
# ( 1 / 306 ) Indian Restaurants in College Point, Queens:0
# ( 1 / 306 ) Indian Restaurants in Whitestone, Queens:0
# ( 1 / 306 ) Indian Restaurants in Bayside, Queens:3
# ( 1 / 306 ) Indian Restaurants in Auburndale, Queens:0
# ( 1 / 306 ) Indian Restaurants in Little Neck, Queens:0
# ( 1 / 306 ) Indian Restaurants in Douglaston, Queens:0
# ( 1 / 306 ) Indian Restaurants in Glen Oaks, Queens:4
# ( 1 / 306 ) Indian Restaurants in Bellerose, Queens:1
# ( 1 / 306 ) Indian Restaurants in Kew Gardens Hills, Queens:1
# ( 1 / 306 ) Indian Restaurants in Fresh Meadows, Queens:0
# ( 1 / 306 ) Indian Restaurants in Briarwood, Queens:3
# ( 1 / 306 ) Indian Restaurants in Jamaica Center, Queens:3
# ( 1 / 306 ) Indian Restaurants in Oakland Gardens, Queens:0
# ( 1 / 306 ) Indian Restaurants in Queens Village, Queens:0
# ( 1 / 306 ) Indian Restaurants in Hollis, Queens:0
# ( 1 / 306 ) Indian Restaurants in South Jamaica, Queens:0
# ( 1 / 306 ) Indian Restaurants in St. Albans, Queens:0
# ( 1 / 306 ) Indian Restaurants in Rochdale, Queens:0
# ( 1 / 306 ) Indian Restaurants in Springfield Gardens, Queens:0
# ( 1 / 306 ) Indian Restaurants in Cambria Heights, Queens:0
# ( 1 / 306 ) Indian Restaurants in Rosedale, Queens:0
# ( 1 / 306 ) Indian Restaurants in Far Rockaway, Queens:0
# ( 1 / 306 ) Indian Restaurants in Broad Channel, Queens:0
# ( 1 / 306 ) Indian Restaurants in Breezy Point, Queens:0
# ( 1 / 306 ) Indian Restaurants in Steinway, Queens:1
# ( 1 / 306 ) Indian Restaurants in Beechhurst, Queens:0
# ( 1 / 306 ) Indian Restaurants in Bay Terrace, Queens:0
# ( 1 / 306 ) Indian Restaurants in Edgemere, Queens:0
# ( 1 / 306 ) Indian Restaurants in Arverne, Queens:0
# ( 1 / 306 ) Indian Restaurants in Rockaway Beach, Queens:0
# ( 1 / 306 ) Indian Restaurants in Neponsit, Queens:0
# ( 1 / 306 ) Indian Restaurants in Murray Hill, Queens:0
# ( 1 / 306 ) Indian Restaurants in Floral Park, Queens:9
# ( 1 / 306 ) Indian Restaurants in Holliswood, Queens:1
# ( 1 / 306 ) Indian Restaurants in Jamaica Estates, Queens:1
# ( 1 / 306 ) Indian Restaurants in Queensboro Hill, Queens:0
# ( 1 / 306 ) Indian Restaurants in Hillcrest, Queens:0
# ( 1 / 306 ) Indian Restaurants in Ravenswood, Queens:1
# ( 1 / 306 ) Indian Restaurants in Lindenwood, Queens:0
# ( 1 / 306 ) Indian Restaurants in Laurelton, Queens:0
# ( 1 / 306 ) Indian Restaurants in Lefrak City, Queens:0
# ( 1 / 306 ) Indian Restaurants in Belle Harbor, Queens:0
# ( 1 / 306 ) Indian Restaurants in Rockaway Park, Queens:0
# ( 1 / 306 ) Indian Restaurants in Somerville, Queens:0
# ( 1 / 306 ) Indian Restaurants in Brookville, Queens:0
# ( 1 / 306 ) Indian Restaurants in Bellaire, Queens:1
# ( 1 / 306 ) Indian Restaurants in North Corona, Queens:0
# ( 1 / 306 ) Indian Restaurants in Forest Hills Gardens, Queens:0
# ( 1 / 306 ) Indian Restaurants in St. George, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in New Brighton, Staten Island:1
# ( 1 / 306 ) Indian Restaurants in Stapleton, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Rosebank, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in West Brighton, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Grymes Hill, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Todt Hill, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in South Beach, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Port Richmond, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Mariner's Harbor, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Port Ivory, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Castleton Corners, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in New Springville, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Travis, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in New Dorp, Staten Island:1
# ( 1 / 306 ) Indian Restaurants in Oakwood, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Great Kills, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Eltingville, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Annadale, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Woodrow, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Tottenville, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Tompkinsville, Staten Island:1
# ( 1 / 306 ) Indian Restaurants in Silver Lake, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Sunnyside, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Ditmas Park, Brooklyn:2
# ( 1 / 306 ) Indian Restaurants in Wingate, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Rugby, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Park Hill, Staten Island:1
# ( 1 / 306 ) Indian Restaurants in Westerleigh, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Graniteville, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Arlington, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Arrochar, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Grasmere, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Old Town, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Dongan Hills, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Midland Beach, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Grant City, Staten Island:1
# ( 1 / 306 ) Indian Restaurants in New Dorp Beach, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Bay Terrace, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Huguenot, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Pleasant Plains, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Butler Manor, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Charleston, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Rossville, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Arden Heights, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Greenridge, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Heartland Village, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Chelsea, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Bloomfield, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Bulls Head, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Carnegie Hill, Manhattan:2
# ( 1 / 306 ) Indian Restaurants in Noho, Manhattan:0
# ( 1 / 306 ) Indian Restaurants in Civic Center, Manhattan:1
# ( 1 / 306 ) Indian Restaurants in Midtown South, Manhattan:2
# ( 1 / 306 ) Indian Restaurants in Richmond Town, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Shore Acres, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Clifton, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Concord, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Emerson Hill, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Randall Manor, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Howland Hook, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Elm Park, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Remsen Village, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in New Lots, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Paerdegat Basin, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Mill Basin, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Jamaica Hills, Queens:4
# ( 1 / 306 ) Indian Restaurants in Utopia, Queens:0
# ( 1 / 306 ) Indian Restaurants in Pomonok, Queens:0
# ( 1 / 306 ) Indian Restaurants in Astoria Heights, Queens:2
# ( 1 / 306 ) Indian Restaurants in Claremont Village, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Concourse Village, Bronx:1
# ( 1 / 306 ) Indian Restaurants in Mount Eden, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Mount Hope, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Sutton Place, Manhattan:1
# ( 1 / 306 ) Indian Restaurants in Hunters Point, Queens:0
# ( 1 / 306 ) Indian Restaurants in Turtle Bay, Manhattan:2
# ( 1 / 306 ) Indian Restaurants in Tudor City, Manhattan:1
# ( 1 / 306 ) Indian Restaurants in Stuyvesant Town, Manhattan:1
# ( 1 / 306 ) Indian Restaurants in Flatiron, Manhattan:0
# ( 1 / 306 ) Indian Restaurants in Sunnyside Gardens, Queens:0
# ( 1 / 306 ) Indian Restaurants in Blissville, Queens:1
# ( 1 / 306 ) Indian Restaurants in Fulton Ferry, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Vinegar Hill, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Weeksville, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Broadway Junction, Brooklyn:1
# ( 1 / 306 ) Indian Restaurants in Dumbo, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Manor Heights, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Willowbrook, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Sandy Ground, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Egbertville, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Roxbury, Queens:0
# ( 1 / 306 ) Indian Restaurants in Homecrest, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Middle Village, Queens:0
# ( 1 / 306 ) Indian Restaurants in Prince's Bay, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Lighthouse Hill, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Richmond Valley, Staten Island:0
# ( 1 / 306 ) Indian Restaurants in Malba, Queens:0
# ( 1 / 306 ) Indian Restaurants in Highland Park, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Madison, Brooklyn:0
# ( 1 / 306 ) Indian Restaurants in Bronxdale, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Allerton, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Kingsbridge Heights, Bronx:0
# ( 1 / 306 ) Indian Restaurants in Erasmus, Brooklyn:2
# ( 1 / 306 ) Indian Restaurants in Hudson Yards, Manhattan:0
# ( 1 / 306 ) Indian Restaurants in Hammels, Queens:0
# ( 1 / 306 ) Indian Restaurants in Bayswater, Queens:0
# ( 1 / 306 ) Indian Restaurants in Queensbridge, Queens:2
# ( 1 / 306 ) Indian Restaurants in Fox Hills, Staten Island:1

# %%
indian_rest_ny.head()
# Out:
#   Borough    Neighborhood                        ID  \
# 0   Bronx        Woodlawn  4c0448d9310fc9b6bf1dc761
# 1   Bronx     Parkchester  4c194631838020a13e78e561
# 2   Bronx  Spuyten Duyvil  4c04544df423a593ac83d116
# 3   Bronx       Concourse  551b7f75498e86c00a0ed2e1
# 4   Bronx       Unionport  4c194631838020a13e78e561
#
#                           Name
# 0                   Curry Spot
# 1  Melanies Roti Bar And Grill
# 2         Cumin Indian Cuisine
# 3                  Hungry Bird
# 4  Melanies Roti Bar And Grill

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Indian Restaurants for each Borough in New York City')
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('No.of Indian Restaurants', fontsize=15)
#giving a bar plot
indian_rest_ny.groupby('Borough')['ID'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Indian Restaurants for each Neighborhood in New York City')
#On x-axis
plt.xlabel('Neighborhood', fontsize = 15)
#On y-axis
plt.ylabel('No.of Indian Restaurants', fontsize=15)
#giving a bar plot
indian_rest_ny.groupby('Neighborhood')['ID'].count().nlargest(5).plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
indian_rest_ny[indian_rest_ny['Neighborhood']=='Floral Park']
# Out:
#     Borough Neighborhood                        ID                       Name
# 108  Queens  Floral Park  527ffc0811d2d329d5e49abd              Jackson Diner
# 109  Queens  Floral Park  4e4e3e22bd4101d0d7a5c2d1             Kerala Kitchen
# 110  Queens  Floral Park  4b647b56f964a520c4b62ae3   Usha Foods & Usha Sweets
# 111  Queens  Floral Park  4b787c49f964a5209cd12ee3  Santoor Indian Restaurant
# 112  Queens  Floral Park  4c0c01e0bbc676b00d6b4cd5              Mumbai Xpress
# 113  Queens  Floral Park  4c76ff35a5676dcb72671721            Flavor Of India
# 114  Queens  Floral Park  4df0f39dd4c04d0392c853ea              Sagar Chinese
# 115  Queens  Floral Park  5d06c43cc03635002cc463f2                     Honest
# 116  Queens  Floral Park  4e6bfe1c7d8b2c711b17bbe5    Surya sweets and snacks

# %%
# prepare neighborhood list that contains indian resturants
column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
indian_rest_stats_ny=pd.DataFrame(columns=column_names)
count=1


for row in indian_rest_ny.values.tolist():
    Borough,Neighborhood,ID,Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,rating,tips=[0]*5
    print('(',count,'/',len(indian_rest_ny),')','processed')
    indian_rest_stats_ny = indian_rest_stats_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
# Out:
#                          ID        Name  Likes  Rating  Tips
# 0  4c0448d9310fc9b6bf1dc761  Curry Spot      5     7.7    10
# ( 1 / 152 ) processed
#                          ID                         Name  Likes  Rating  Tips
# 0  4c194631838020a13e78e561  Melanies Roti Bar And Grill      3     6.2     2
# ( 2 / 152 ) processed
#                          ID                  Name  Likes  Rating  Tips
# 0  4c04544df423a593ac83d116  Cumin Indian Cuisine     13     5.8     9
# ( 3 / 152 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  551b7f75498e86c00a0ed2e1  Hungry Bird      8     7.0     3
# ( 4 / 152 ) processed
#                          ID                         Name  Likes  Rating  Tips
# 0  4c194631838020a13e78e561  Melanies Roti Bar And Grill      3     6.2     2
# ( 5 / 152 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4b5a4dc8f964a520a2bb28e3  Taj Mahal     37     8.3    26
# ( 6 / 152 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4af0d31bf964a5207ddf21e3  Pak Nasheman      9     7.4     4
# ( 7 / 152 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  52213c4211d295d4c57a607c  Ashoka Grill      8     7.5    14
# ( 8 / 152 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  564d283d498e6e851df79d87  Great Indian Curry      3     6.1     2
# ( 9 / 152 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  512a9ea9e4b004fb8eeb84e5  Silver Krust     13     8.4     3
# ( 10 / 152 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4db0f4371e729fcc56497f20  Mashallah     20     7.5     7
# ( 11 / 152 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  4b718914f964a520c04b2de3  Madina Restaurant and Sweets     17     6.3    13
# ( 12 / 152 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  592e1dae345cbe0fc77cf6c9  Diwan Grill     19     8.9     8
# ( 13 / 152 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  57596dad498e732300496b23  Dosa Royale     78     8.4    24
# ( 14 / 152 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  57596dad498e732300496b23  Dosa Royale     78     8.4    24
# ( 15 / 152 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  543870ec498ec64de510608d  Masala Grill     40     8.2    14
# ( 16 / 152 ) processed
#                          ID                        Name  Likes  Rating  Tips
# 0  4bb93b70cf2fc9b6fe64a002  Gandhi Fine Indian Cuisine     83     8.6    49
# ( 17 / 152 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  4afdf78bf964a520862c22e3  King of Tandoor     25     7.4    23
# ( 18 / 152 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  5539753f498edbace4746b67  Tandoori Masala     12     8.0     2
# ( 19 / 152 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  4f6cae2ee4b0d4a5afcef5c0  Delhi Heights     22     8.0     8
# ( 20 / 152 ) processed
#                          ID                     Name  Likes  Rating  Tips
# 0  519ff6c8498e1300ddcbd45c  Anarkali Indian Cuisine     14     7.6     8
# ( 21 / 152 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4db0f4371e729fcc56497f20  Mashallah     20     7.5     7
# ( 22 / 152 ) processed
#                          ID            Name  Likes  Rating  Tips
# 0  5514551f498e89f59ce53e5a  Indian Kitchen     10     7.7     7
# ( 23 / 152 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  5631511b498e3d6d7e0a4df0  Tikka Indian Grill     95     8.4    29
# ( 24 / 152 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  5631511b498e3d6d7e0a4df0  Tikka Indian Grill     95     8.4    29
# ( 25 / 152 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  545835a1498e820edc6f636f  Bombay Grill     14     7.1     4
# ( 26 / 152 ) processed
#                          ID                      Name  Likes  Rating  Tips
# 0  4ae7876ef964a5201eac21e3  Kismat Indian Restaurant     46     7.9    25
# ( 27 / 152 ) processed
#                          ID                           Name  Likes  Rating  \
# 0  54c2bd96498eaf5142e3fe92  Clove Indian Restaurant & Bar     33     7.7
#
#    Tips
# 0    17
# ( 28 / 152 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  5914ff32b23dfa207eca38de  Mumbai Masala     14     7.6     7
# ( 29 / 152 ) processed
#                          ID                 Name  Likes  Rating  Tips
# 0  529d382a11d2dd5ef107e641  Chapati House - NYC     73     7.6    18
# ( 30 / 152 ) processed
#                          ID                           Name  Likes  Rating  \
# 0  54c2bd96498eaf5142e3fe92  Clove Indian Restaurant & Bar     33     7.7
#
#    Tips
# 0    17
# ( 31 / 152 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  56d87f3d498ee215abee5724  Delhi Masala     14     8.4     3
# ( 32 / 152 ) processed
#                          ID                           Name  Likes  Rating  \
# 0  54c2bd96498eaf5142e3fe92  Clove Indian Restaurant & Bar     33     7.7
#
#    Tips
# 0    17
# ( 33 / 152 ) processed
#                          ID      Name  Likes  Rating  Tips
# 0  519fe6f5498e30595d370c44  Bawarchi      9     7.5     4
# ( 34 / 152 ) processed
#                          ID            Name  Likes  Rating  Tips
# 0  5272ca4511d22488f6895caf  Drunken Munkey    215     8.6    62
# ( 35 / 152 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  56ed855a498ef3bb022352c3  Mughlai Indian Cuisine     28     8.1    10
# ( 36 / 152 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  4fe4fb50c2eee335e4fea69d  Moti Mahal Delux    186     7.8    83
# ( 37 / 152 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  4b0dec08f964a520ae5223e3  Alachi Masala     18     7.8    17
# ( 38 / 152 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  591890f43abcaf1ddca66e85  Ashoka     22     8.5     9
# ( 39 / 152 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  42489a80f964a5208b201fe3  Swagat    108     8.5    40
# ( 40 / 152 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  49d91c12f964a520015e1fe3  The Kati Roll Company    831     8.6   255
# ( 41 / 152 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  59fcd48c464d6567ed2f5e37  The Kati Roll Company     21     8.8     4
# ( 42 / 152 ) processed
#                          ID               Name  Likes  Rating  Tips
# 0  4b4aab62f964a520978c26e3  Dil-e Punjab Deli    109     8.7    44
# ( 43 / 152 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  4bbb9dbded7776b0e1ad3e51  Tamarind TriBeCa    601     9.0   150
# ( 44 / 152 ) processed
#                          ID  Name  Likes  Rating  Tips
# 0  591794df2be42556988e4a8e  Rahi    120     8.8    26
# ( 45 / 152 ) processed
#                          ID        Name  Likes  Rating  Tips
# 0  4d24b812836f5481518645f7  Doaba Deli     42     7.9    13
# ( 46 / 152 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  424de080f964a520ae201fe3  Manhattan Valley     42     7.9    30
# ( 47 / 152 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  49c5ad0af964a5201b571fe3  Roti Roll    116     8.0    58
# ( 48 / 152 ) processed
#                          ID   Name  Likes  Rating  Tips
# 0  538ba1f2498e279098e4210a  Awadh     51     7.9    13
# ( 49 / 152 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  49c5ad0af964a5201b571fe3  Roti Roll    116     8.0    58
# ( 50 / 152 ) processed
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-10411ff430c3> in <module>
#       8     Borough,Neighborhood,ID,Name=row
#       9     try:
# ---> 10         venue_details=get_venue_details(ID)
#      11         print(venue_details)
#      12         id,name,likes,rating,tips=venue_details.values.tolist()[0]
#
# <ipython-input-4-81936f80231d> in get_venue_details(venue_id)
#      14     # get all the data
#      15     results = requests.get(url).json()
# ---> 16     venue_data=results['response']['venue']
#      17     venue_details=[]
#      18     try:
#
# KeyError: 'venue'

# %%
indian_rest_stats_ny.head()
# Out:
#   Borough    Neighborhood                        ID  \
# 0   Bronx        Woodlawn  4c0448d9310fc9b6bf1dc761
# 1   Bronx     Parkchester  4c194631838020a13e78e561
# 2   Bronx  Spuyten Duyvil  4c04544df423a593ac83d116
# 3   Bronx       Concourse  551b7f75498e86c00a0ed2e1
# 4   Bronx       Unionport  4c194631838020a13e78e561
#
#                           Name Likes  Rating Tips
# 0                   Curry Spot     5     7.7   10
# 1  Melanies Roti Bar And Grill     3     6.2    2
# 2         Cumin Indian Cuisine    13     5.8    9
# 3                  Hungry Bird     8     7.0    3
# 4  Melanies Roti Bar And Grill     3     6.2    2

# %%
indian_rest_stats_ny.shape
# Out:
# (50, 7)

# %%
indian_rest_ny.shape
# Out:
# (152, 4)

# %%
indian_rest_stats_ny.to_csv('indian_rest_stats_ny.csv', index=False)

# %%
indian_rest_stats_ny_csv=pd.read_csv('indian_rest_stats_ny.csv')

# %%
indian_rest_stats_ny_csv.shape
# Out:
# (50, 7)

# %%
indian_rest_stats_ny_csv.head()
# Out:
#   Borough    Neighborhood                        ID  \
# 0   Bronx        Woodlawn  4c0448d9310fc9b6bf1dc761
# 1   Bronx     Parkchester  4c194631838020a13e78e561
# 2   Bronx  Spuyten Duyvil  4c04544df423a593ac83d116
# 3   Bronx       Concourse  551b7f75498e86c00a0ed2e1
# 4   Bronx       Unionport  4c194631838020a13e78e561
#
#                           Name  Likes  Rating  Tips
# 0                   Curry Spot      5     7.7    10
# 1  Melanies Roti Bar And Grill      3     6.2     2
# 2         Cumin Indian Cuisine     13     5.8     9
# 3                  Hungry Bird      8     7.0     3
# 4  Melanies Roti Bar And Grill      3     6.2     2

# %%
indian_rest_stats_ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
# Borough         50 non-null object
# Neighborhood    50 non-null object
# ID              50 non-null object
# Name            50 non-null object
# Likes           50 non-null object
# Rating          50 non-null float64
# Tips            50 non-null object
# dtypes: float64(1), object(6)
# memory usage: 2.8+ KB

# %%
indian_rest_stats_ny['Likes']=indian_rest_stats_ny['Likes'].astype('float64')

# %%
indian_rest_stats_ny['Tips']=indian_rest_stats_ny['Tips'].astype('float64')

# %%
indian_rest_stats_ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
# Borough         50 non-null object
# Neighborhood    50 non-null object
# ID              50 non-null object
# Name            50 non-null object
# Likes           50 non-null float64
# Rating          50 non-null float64
# Tips            50 non-null float64
# dtypes: float64(3), object(4)
# memory usage: 2.8+ KB

# %%
# Resturant with maximum Likes
indian_rest_stats_ny.iloc[indian_rest_stats_ny['Likes'].idxmax()]
# Out:
# Borough                        Manhattan
# Neighborhood                     Midtown
# ID              49d91c12f964a520015e1fe3
# Name               The Kati Roll Company
# Likes                                831
# Rating                               8.6
# Tips                                 255
# Name: 40, dtype: object

# %%
# Resturant with maximum Rating
indian_rest_stats_ny.iloc[indian_rest_stats_ny['Rating'].idxmax()]
# Out:
# Borough                        Manhattan
# Neighborhood                     Tribeca
# ID              4bbb9dbded7776b0e1ad3e51
# Name                    Tamarind TriBeCa
# Likes                                601
# Rating                                 9
# Tips                                 150
# Name: 43, dtype: object

# %%
# Resturant with maximum Tips
indian_rest_stats_ny.iloc[indian_rest_stats_ny['Tips'].idxmax()]
# Out:
# Borough                        Manhattan
# Neighborhood                     Midtown
# ID              49d91c12f964a520015e1fe3
# Name               The Kati Roll Company
# Likes                                831
# Rating                               8.6
# Tips                                 255
# Name: 40, dtype: object

# %%
ny_neighborhood_stats=indian_rest_stats_ny.groupby('Neighborhood',as_index=False).mean()[['Neighborhood','Rating']]
ny_neighborhood_stats.columns=['Neighborhood','Average Rating']

# %%
ny_neighborhood_stats.sort_values(['Average Rating'],ascending=False).head(10)
# Out:
#         Neighborhood  Average Rating
# 29           Tribeca             9.0
# 23  Prospect Heights             8.9
# 33      West Village             8.8
# 19       Murray Hill             8.8
# 4            Chelsea             8.7
# 17           Midtown             8.6
# 5       Clinton Hill             8.4
# 27        South Side             8.4
# 7      East Flatbush             8.4
# 20        North Side             8.4

# %%
ny_borough_stats=indian_rest_stats_ny.groupby('Borough',as_index=False).mean()[['Borough','Rating']]
ny_borough_stats.columns=['Borough','Average Rating']

# %%
ny_borough_stats.sort_values(['Average Rating'],ascending=False).head()
# Out:
#      Borough  Average Rating
# 2  Manhattan        8.125000
# 1   Brooklyn        7.814286
# 0      Bronx        6.580000

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Average rating of Indian Resturants for each Borough')
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('Average Rating', fontsize=15)
#giving a bar plot
indian_rest_stats_ny.groupby('Borough').mean()['Rating'].plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
ny_neighborhood_stats=ny_neighborhood_stats[ny_neighborhood_stats['Average Rating']>=9.0]
ny_neighborhood_stats
# Out:
#    Neighborhood  Average Rating
# 29      Tribeca             9.0

# %%
ny_neighborhood_stats=pd.merge(ny_neighborhood_stats,new_york_data, on='Neighborhood')
ny_neighborhood_stats=ny_neighborhood_stats[['Borough','Neighborhood','Latitude','Longitude','Average Rating']]
ny_neighborhood_stats
# Out:
#      Borough Neighborhood   Latitude  Longitude  Average Rating
# 0  Manhattan      Tribeca  40.721522 -74.010683             9.0

# %%
# create map and display it
ny_map = folium.Map(location=geo_location('New York'), zoom_start=12)


# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in ny_neighborhood_stats[['Latitude','Longitude']].values:
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# %%
ny_neighborhood_stats['Label']=ny_neighborhood_stats['Neighborhood']+', '+ny_neighborhood_stats['Borough']+'('+ny_neighborhood_stats['Average Rating'].map(str)+')'

# %%
# add pop-up text to each marker on the map
for lat, lng, label in ny_neighborhood_stats[['Latitude','Longitude','Label']].values:
    folium.Marker([lat, lng], popup=label).add_to(ny_map)        
# add incidents to map
ny_map.add_child(incidents)

# %%
Results 1.We see that Queens has the highest number of Neighbourhoods.
Conclusion
Astoria(Queens), Blissville(Queens), Civic Center(Manhattan) are some of the best neighborhoods for indian cuisine.
Manhattan have potential Indian Resturant Market/
Staten Island ranks last in average rating of Indian Resturants.
